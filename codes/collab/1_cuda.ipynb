# %%
# %%writefile hello.c
#
# #include <stdio.h>
#
# int main(){
#    printf("Hello World! \n");
#    return 0;
#
# }
# Out:
# Overwriting hello.c

# %%
# !gcc -o hello hello.c
# !./hello
# Out:
# Hello World!
